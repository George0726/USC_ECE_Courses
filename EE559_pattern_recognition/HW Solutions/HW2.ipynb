# %% [markdown]
# ## EE559 HW2

# %% [markdown]
# ### Qirui Sun

# %% [markdown]
# ####  1 . Assune that in a c-class classiﬁcation problem, we have k features $ X_1,X_2,X_3,...,X_k $ that are independent and $ X_j|w_i \tilde{} Gamma(p_i,	\lambda_j)$, i.e. $ p_{X_j|w_i}(x_j|w_i) = \frac{1}{\Gamma_{(p_i)}}\lambda_j^{p_i}x_j^{p_i-1}e^{-\lambda_jx_j}$, $p_i$,$\lambda_j$>0

# %% [markdown]
# ##### (a) Determine the Bayes’ optimal classiﬁer’s decision rule making the general assumption that the prior probability of the classes are diﬀerent.

# %% [markdown]
# Owing to $ X_1,X_2,X_3,...,X_k $ are conditional independent,
# $$ p_{X|w_i}(X|w_i) = p_{X_1,X_2,...X_k|w_i}(x_1,x_2,...x_k|w_i)
# = p_{X_1|w_i}(x_1|w_i)p_{X_2|w_i}(x_2|w_i)...p_{X_k|w_i}(x_k|w_i)$$
# $$\Rightarrow P_{X|w_i}(x|w_i) =( \frac{1}{\Gamma_{(p_i)}})^k\prod_{j =1}^k\lambda_j^{p_i}x_j^{p_i-1}e^{-\lambda_jx_j}$$

# %% [markdown]
# $$p_{w_i|X}(w_i|x)= \frac{P_{X|w_i}(x|w_i)P(w_i)}{P(X)}$$

# %% [markdown]
# The classifier's decision is $w_i^* $ ,
# $$ w_i^* = argmax(p_{w_i|X}(w_i|x))$$

# %% [markdown]
# ##### (b) When are the decision boundaries linear functions of $ x_1,x_2,...,x_k$?

# %% [markdown]
# For choosing $w_i$,\
# $$\Rightarrow p_{w_i|X}(w_i|X)\geq p_{w_j|X}(w_j|X) $$
# $$\Rightarrow\frac{p_{X|w_i}(X|w_i)P(w_i)}{P(X)}\geq\frac{p_{X|w_j}(X|w_j)P(w_j)}{p(X)}$$
# $$\Rightarrow\frac{p_{X|w_i}(X|w_i)}{p_{X|w_j}(X|w_j)} \geq \frac{P(w_j)}{p(w_i)}$$
# $$\Rightarrow\frac{\prod_{r=1}^{k}P_{X_r|w_i}(x_r|w_i)}{\prod_{r=1}^{k}P_{X_r|w_j}(x_r|w_j)}\geq\frac{P(w_j)}{p(w_i)} $$

# %% [markdown]
# According to the problem,\
# $\quad p_{X_j|w_i}(x_j|w_i) = \frac{1}{\Gamma_{(p_i)}}\lambda_j^{p_i}x_j^{p_i-1}e^{-\lambda_jx_j}$, \
# $\Longrightarrow\prod_{r=1}^{k}P_{X_r|w_i}(x_r|w_i) =\prod_{r=1}^{k}\frac{1}{\Gamma_{(p_i)}}\lambda_j^{p_i}x_j^{p_i-1}e^{-\lambda_jx_j} $\
# $P_{X|w_i}(x|w_i) =( \frac{1}{\Gamma_{(p_i)}})^k\prod_{r =1}^k\lambda_r^{p_i}x_r^{p_i-1}e^{-\lambda_rx_r}$

# %% [markdown]
# So the inequation should be,\
# $$\frac{( \frac{1}{\Gamma_{(p_i)}})^k\prod_{r =1}^k\lambda_r^{p_i}x_r^{p_i-1}e^{-\lambda_rx_r}}{( \frac{1}{\Gamma_{(p_j)}})^k\prod_{r =1}^k\lambda_r^{p_j}x_r^{p_j-1}e^{-\lambda_rx_r}}\geq \frac{P(w_j)}{P(w_i)} $$

# %% [markdown]
# $$\Rrightarrow(\frac{\Gamma_{(p_j)}}{\Gamma_{(p_i)}})^k
# (\lambda_1\lambda_2...\lambda_k)^{P_i-P_j}(x_1x_2...x_k)^{P_i-P_j}\geq \frac{P(w_j)}{P(w_i)}$$

# %% [markdown]
# So there is no posibility to have the linear functions of $x_1,x_2,...x_k$

# %% [markdown]
# ##### (c) Assuming that p1 = 4,p2 = 2,c = 2,k = 4,λ1 = λ3 = 1,λ2 = λ4 = 2, and that the prior probabilites of each class are equal, classify x = (0.1,0.2,0.3,4).

# %% [markdown]
# $\gamma(p_1) = \gamma(4) = 6$\
# $\gamma(p_2) = \gamma(2) = 1$

# %% [markdown]
# For $w^* = w_1$
# $$(\frac{\Gamma_{(p_2)}}{\Gamma_{(p_1)}})^k(\lambda_1\lambda_2\lambda_3\lambda_4)^{P_1-P_2}(x_1x_2x_3x_4)^{P_1-P_2}\geq \frac{P(w_2)}{P(w_1)}$$

# %% [markdown]
# $(\frac{\Gamma_{(p_2)}}{\Gamma_{(p_1)}})^4(\lambda_1\lambda_2\lambda_3\lambda_4)^{P_1-P_2}(x_1x_2x_3x_4)^{P_1-P_2} $\
# $ = \frac{1}{6^4}(1\times2\times1\times2)^{4-2}\times({0.1\times0.2\times0.3\times4})^{4-2} $\
# = $6.94 \times 10^{-6}$ <1

# %% [markdown]
# So $w^* = w_2$

# %% [markdown]
# ##### (d) Assuming that $p_1 = 3.2,p_2 = 8,c = 2,k = 1,λ_1 = 1$, and that the prior probabilites of each class are equal, ﬁnd the decision boundary$ x = x^∗$. Also, ﬁnd the probability of type-1 and type-2 errors.

# %% [markdown]
# For $w^* = w_1$

# %% [markdown]
# $$\frac{\Gamma_{(p_2)}}{\Gamma_{(p_1)}}(\lambda_1)^{P_1-P_2}(x_1)^{P_1-P_2} \geq \frac{P(w_2)}{P(w_1)}
# \Rightarrow \frac{\Gamma(8)}{\Gamma(3.2)}\times(1)^{3.2-8}\times x_1^{3.2-8} \geq 1 $$

# %% [markdown]
# $$x_1 \leq (\frac{Γ(8)}{Γ(3.2)})^{\frac{5}{24}}$$

# %% [markdown]
# So the boundary, $x^* =(\frac{\gamma(8)}{\gamma(3.2)})^{\frac{5}{24}} =4.9117$

# %% [markdown]
# $$
# P_{X|w_i}(x|w_i) =( \frac{1}{\Gamma_{(p_i)}})^k\prod_{r =1}^k\lambda_r^{p_i}x_r^{p_i-1}e^{-\lambda_rx_r}\
# $$

# %% [markdown]
# $$
# P_{X|w_1}(x|w_1) =  \frac{1}{\Gamma_{(p_1)}}\lambda_1^{p_1}x^{p_1-1}e^{-x}\
# = \frac{1}{\Gamma(3.2)}x^{2.2}e^{-x}
# $$

# %% [markdown]
# $$
# P_{X|w_2}(x|w_2) =  \frac{1}{\Gamma_{(p_2)}}\lambda_1^{p_2}x^{p_2-1}e^{-x}\
# = \frac{1}{\Gamma(8)}x^{7}e^{-x}
# $$

# %% [markdown]
# For prior probability, $P(\omega_1) = P(\omega_2) =1/2$

# %% [markdown]
# For $w_1$ is positive, the Type I error is FP,
# $$P(Type \quad I \quad Error)=\int_{x^*}^{\infty} P_{X|w_1}(x|w_1)P(w_1)dx$$
# $$P(Type\quad I \quad Error)= 0.07861$$

# %% [markdown]
# The Type II error is FN,
# $$P(Type \quad II\quad Error) = \int_{-\infty}^{x^*} P_{X|w_2}(x|w_2)P(w_2)dx$$
# $$P(Type\quad II \quad Error)= 0.06216$$

# %% [markdown]
# For $w_2$ is positive, the situation is on the contrary,
# $$P(Type\quad II \quad Error)= 0.07861$$
# $$P(Type\quad I \quad Error)= 0.06216$$

# %% [markdown]
# ##### (e) Assuming that $p_1 = p_2 = 4,c = 2,k = 2,λ_1 = 8,λ_2 = 0.3$, and $P(ω_1) = 1/4,P(ω_2) = 3/4$, ﬁnd the decision boundary $f(x_1,x_2) = 0$.

# %% [markdown]
# For $w^* = w_1$,
# $$(\frac{\Gamma(4)}{\Gamma(4)})^2(\lambda_1\lambda_2)^{4-4}(x_1x_2)^{4-4} \geq \frac{P(w_2)}{P(w_1)} $$

# %% [markdown]
# Owing to the left hand side of equation is 1, while the right hand side equation is 3.

# %% [markdown]
# **So the inequation will not hold. Hence, there answer is $w^* = w_2$ and there is no decision boundary**

# %% [markdown]
# #### 2. Assume that in a c-class classiﬁcation problem, there are k independent features and $X_i|ω_j ∼ Lap(m_{ij},λ_i), i.e. p_{X_i}|ω_j(x_i|ω_j) = \frac{λ_i}{2} e^{−λ_i|x_i−m_{ij}|},λ_i > 0,i ∈ \{1,2,...,k\},j ∈ {\{1,2,...,c}\}$.
# #### Assuming that the prior class probabilities are equal, show that the minimum error rate classiﬁer is also a minimum weighted Manhattan distance (or weighted L1-distance) classiﬁer. When does the minimum error rate classiﬁer becomes the minimum Manhattan distance classiﬁer?

# %% [markdown]
# Owing to the k independent features $X_i|w_j$,
# $$ p_{X|w_j}(X|w_j) = p_{X_1,X_2,...X_k|w_j}(x_1,x_2,...x_k|w_j)\
# = p_{X_1|w_j}(x_1|w_j)p_{X_2|w_j}(x_2|w_j)...p_{X_k|w_j}(x_k|w_j)$$

# %% [markdown]
# $$ p_{X|w_j}(X|w_j) = (\frac{\prod_{i=1}^k\lambda_i}{2^k})e^{-\sum_{i=1}^k\lambda_i|x_i-m_{ij}|}$$

# %% [markdown]
# For choosing $w_j$,So
# $$p_{w_j|X}(w_j|x)\geq p_{w_r|X}(w_r|x),\forall r ∈ {\{1,2,...,c}\}$$

# %% [markdown]
# According to the Baye's Rule,
# $$\frac{p_{X|w_j}(x|w_j)P(w_j)}{P(x)}\geq \frac{p_{X|w_r}(x|w_r)P(w_r)}{P(x)},\forall r ∈ {\{1,2,...,c}\}$$

# %% [markdown]
# Owing to the prior class probabilities are equal,
# $$\Longrightarrow p_{X|w_j}(x|w_j)\geq p_{X|w_r}(x|w_r)$$

# %% [markdown]
# $$\Longrightarrow(\frac{\prod_{i=1}^k\lambda_i}{2^k})e^{-\sum_{i=1}^k\lambda_i|x_i-m_{ij}|}\geq (\frac{\prod_{i=1}^k\lambda_i}{2^k})e^{-\sum_{i=1}^k\lambda_i|x_i-m_{ir}|}$$

# %% [markdown]
# $$\Longrightarrow e^{-\sum_{i=1}^k\lambda_i(|x_i-m_{ij}|-|x_i-m_{ir}|)}\geq1$$

# %% [markdown]
# Take the log for the inequality,
# $$\Longrightarrow \sum_{i=1}^k\lambda_i|x_i-m_{ij}|\leq\sum_{i=1}^k\lambda_i|x_i-m_{ir}|,\forall r \in{\{1,2,...,c}\}$$
# which is the same as minimun weighted Manhattan distance classifier

# %% [markdown]
# **So he minimum error rate classiﬁer is also a minimum weighted Manhattan distance (or weighted L1-distance) classiﬁer.**

# %% [markdown]
# When **the weights are the same**, the minimum error rate classiﬁer becomes the minimum Manhattan distance classiﬁer,
# $$\lambda_i = \lambda_j,\forall i,j\in \{1,2,...,k\}$$
# $$i.e.\lambda_1=\lambda_2=\lambda_3=...\lambda_k $$

# %% [markdown]
# #### 3. The class-conditional density functions of a discrete random variable X for four pattern classes are shown below:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# The loss function $λ(α_i|ω_j) $is summarized in the following table, where action $α_i$ means decide pattern class $ω_i$:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Assume $P(ω_1) = 1/10,P(ω_2) = 1/5,P(ω_3) = 1/2,P(ω_4) = 1/5$.

# %% [markdown]
# #####  (a) Compute the conditional risk for each action as:

# %% [markdown]
# First, compute P(x) by the equation,
# $$P(x) = p(x|\omega_1)p(\omega_1)+p(x|\omega_2)p(\omega_2)+p(x|\omega_3)p(\omega_3)+p(x|\omega_4)p(\omega_4)$$

# %% [markdown]
# $$p(x=1) = 89/300$$
# $$p(x =2) =33/100$$
# $$p(x=3) = 28/75$$

# %% [markdown]
# Second, compute$p(\omega_i|x)$ by the Bayes Law,
# $$p(w_i|x) = \frac{p(x|\omega_i)p(\omega_i)}{p(x)}$$

# %% [markdown]
# The results of $p(w_i|x)$ show as table below,

# %% [markdown]
# |x|$\omega_1$|$\omega_2$|$\omega_3$|$\omega_4$|
# |:---:|:---:|:----:|:----:|:---:|
# |1|10/89|30/89| 25/89 |24/89|
# |2| 10/99|5/33| 50/99|8/33|
# |3|5/56|15/112| 75/112|3/28|

# %% [markdown]
# Then, compute the $R(\alpha_i|x)$ by the equation:
# $$R(\alpha_i|x) = \sum_{j=4}^4\lambda(\alpha_i|\omega_j)p(\omega_j|x)$$

# %% [markdown]
# So the risk shows as table below,

# %% [markdown]
# |x|$\alpha_1$|$\alpha_2$|$\alpha_3$|$\alpha_4$|
# |:---:|:---:|:----:|:----:|:---:|
# |1|231/89    |     227/89    |     138/89     |   165/89  |
#   |2|    92/33        |  28/11     |     12/11       |  145/99  | |2
#   |3|   303/112       | 181/112      |    3/4        |   85/56 |

# %% [markdown]
# ##### (b) Compute the overall risk $R$ as:
# $$R = \sum_{i=1}^3R(\alpha(x_i)|x_i)p(x_1)$$
# where $\alpha(x_i)$is the decision rule minimizing the conditional risk for $x_i$.

# %% [markdown]
# According to the minimum error rate classiﬁer, choose the $argmin(R(\alpha_i|x))$ as $\alpha(x_i)$

# %% [markdown]
# So the decision is as below,
# $$\alpha(x=1) = \alpha_3 \quad\alpha(x=2) = \alpha_3\quad\alpha(x=3) = \alpha_3 $$

# %% [markdown]
# $$R = \sum_{i=1}^3R(\alpha(x_i)|x_i)p(x_1)=11/10$$

# %% [markdown]
# #### 4. The following data set was collected to classify people who evade taxes:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Considering relevant features in the table (only one feature is not relevant), assume that the features are independent.

# %% [markdown]
# ##### (a) Estimate prior class probabilities.

# %% [markdown]
# $$P_E(Yes) = \frac{N_{Yes}}{N_{total}} = \frac{3}{10}$$

# %% [markdown]
# $$P_E(No) = \frac{N_{No}}{N_{total}} = \frac{7}{10}$$

# %% [markdown]
# ##### (b) For continuous feature(s), assume conditional Gaussianity and estimate class conditional pdfs $p(x|ω_i)$. Use Maximum Likelihood Estimates.

# %% [markdown]
# Suppose $x_i$ is Taxable income, $y$ is the label evade. Use the maximum likelihood t estimate prarameters $\hat{\mu}$ and $\hat{\sigma}$

# %% [markdown]
# $$f_x(x_1,x_2,...,x_n) = \prod_{i=1}^n \frac{1}{\sqrt{2\pi \hat{\sigma}^2}}e^{\frac{(x_i - \hat{\mu})^2}{2\hat{\sigma}^2}}$$

# %% [markdown]
# $$\Rightarrow ln(f_x(x_1,x_2,...,x_n)) = \sum_{i=1}^n(ln(\frac{1}{\sqrt{2\pi \hat{\sigma}^2}})-\frac{(x_i - \hat{\mu})^2}{2\hat{\sigma}^2})$$

# %% [markdown]
# Assume the derivate is 0,
# $$\frac{d(ln(f_x(x_1,x_2,...,x_n)))}{d\hat{\mu}} = 0 $$
# $$\Rightarrow \sum_{i=1}^n\frac{(x_i - \mu)}{\sigma^2} = 0 $$
# $$\Rightarrow \hat{\mu} = \frac{\sum_{i=1}^n x_i}{n} $$

# %% [markdown]
# Assume the derivate is 0,
# $$\frac{d(ln(f_x(x_1,x_2,...,x_n)))}{d\hat{\sigma}} = 0 $$
# $$\Rightarrow \sum_{i = 1}^n(-\hat{\sigma}^{-1} +\sigma^{-3}(x_i - \hat{\mu})^2)=0$$
# $$\Rightarrow \hat{\sigma}^2 =\frac{\sum_{i = 1}^n(x_i - \hat{\mu})^2}{n}$$

# %% [markdown]
# Considering the estimator is baised, $$E[\hat{\sigma}^2] = \frac{n-1}{n}\sigma^2$$
# So,we change the estimator to unbiase,
# $$\hat{s}^2 = \frac{n}{n-1}\hat{\sigma}^2 = \frac{\sum_{i = 1}^n(x_i - \hat{\mu})^2}{n-1}$$

# %% [markdown]
# For evade is 'Yes':
# $$\hat{\mu} = \frac{88+90+85}{3}=87.67$$
# $$\hat{s}^2 = \frac{\sum_{i = 1}^n(x_i - \hat{\mu})^2}{n-1} =6.33 $$

# %% [markdown]
# Owing to $$P(X_{T.I.} =x_i|\omega_i="Yes") = \frac{1}{\sqrt{2\pi \sigma^2}}e^{\frac{(x_{T.I.} - \mu)^2}{2\sigma^2}} $$

# %% [markdown]
# SO, $$P(X_{T.I.} =x_i|\omega_i="Yes") = \frac{1}{\sqrt{2\pi\times(6.33) }}e^{\frac{(x_{T.I.} - 87.67)^2}{2\times(6.33)}} $$

# %% [markdown]
# For evade is 'No':
# $$\hat{\mu} = \frac{\sum x_i}{\# x_i}=109.14$$
# $$\hat{s}^2 = \frac{\sum_{i = 1}^n(x_i - \hat{\mu})^2}{n-1} = 2539.5$$

# %% [markdown]
# SO, $$P(X_{T.I.} =x_{T.I.}|Y="No") = \frac{1}{\sqrt{2\pi\times(2539.5) }}e^{\frac{(x_{T.I.} - 109.14)^2}{2\times(2539.5)}} $$

# %% [markdown]
# ##### (c) For each discrete feature $X$, assume that the number of instances in class $ω_i$ for which $X = x_j$ is $n_{ji}$ and the number of instances in class $ω_i$ is $n_i$. Estimate the probability mass $p_{X|ω_i}(x_j|ω_i) = P(X = x_j|ω_i)$ as $n_{ji}/n_i$ for each discrete feature. Is this a valid estimate of the pmf?

# %% [markdown]
# For Marital Status,\
# $p_{X_{M.S.}|ω_i}('Single'|'No') = P(M.S. = 'Single'|'No') = 2/7$\
# $p_{X_{M.S.}|ω_i}('Divorsed'|'No') = P(M.S = 'Divorsed'|'No') = 1/7$\
# $p_{X_{M.S.}|ω_i}('Married'|'No') = P(M.S = 'Married'|'No') = 4/7$

# %% [markdown]
# $p_{X_{M.S.}|ω_i}('Single'|'Yes') = P(M.S = 'Single'|'Yes') = 2/3$\
# $p_{X_{M.S.}|ω_i}('Divorsed'|'Yes') = P(M.S= 'Divorsed'|'Yes') = 1/3$\
# $p_{X_{M.S.}|ω_i}('Married'|'Yes') = P(M.S = 'Married'|'Yes') = 0$

# %% [markdown]
# For all conditional probabilities for Marital Status is positive, $\sum p_{X_{M.S.}|ω_i}(x_j|'Yes') = 1$, $\sum p_{X_{M.S.}|ω_i}(x_j|'No') = 1$.For Marital Status,hence,it is a valid pmf.

# %% [markdown]
# For Refund,\
# $p_{X_{R.}|ω_i}('Yes'|'No') = P(R. = 'Yes'|'No') = 3/7$\
# $p_{X_{R.}|ω_i}('No'|'No') = P(R. = 'No'|'No') = 4/7$

# %% [markdown]
# $p_{X_{R.}|ω_i}('Yes'|'Yes') = P(R. = 'Yes'|'Yes') = 0$\
# $p_{X_{R.}|ω_i}('No'|'Yes') = P(R. = 'No'|'Yes') = 1$

# %% [markdown]
# For all conditional probabilities for Refund is positive, $\sum p_{X_{R.}|ω_i}(x_j|'Yes') = 1$, $\sum p_{X_{R.}|ω_i}(x_j|'No') = 1$.For Refund,hence,it is a valid pmf.

# %% [markdown]
# ##### (d) There is an issue with using the estimate you calculated in 4c. Explain why the laplace correction$ (n_{ji}+1)/(n_i+l)$, where $l$ is the number of levels $X$ can assume, solves the problem with the estimate given in 4c. Is this a valid estimate of the pmf?

# %% [markdown]
# For Marital Status,\
# $p_{X_{M.S.}|ω_i}('Single'|'No') = P(M.S. = 'Single'|'No') = 3/10$\
# $p_{X_{M.S.}|ω_i}('Divorsed'|'No') = P(M.S = 'Divorsed'|'No') = 2/10$\
# $p_{X_{M.S.}|ω_i}('Married'|'No') = P(M.S = 'Married'|'No') = 5/10$

# %% [markdown]
# $p_{X_{M.S.}|ω_i}('Single'|'Yes') = P(M.S = 'Single'|'Yes') = 3/6$\
# $p_{X_{M.S.}|ω_i}('Divorsed'|'Yes') = P(M.S= 'Divorsed'|'Yes') = 2/6$\
# $p_{X_{M.S.}|ω_i}('Married'|'Yes') = P(M.S = 'Married'|'Yes') = 1/6$

# %% [markdown]
# For all conditional probabilities for Marital Status is positive, $\sum p_{X_{M.S.}|ω_i}(x_j|'Yes') = 1$, $\sum p_{X_{M.S.}|ω_i}(x_j|'No') = 1$.For Marital Status,hence,it is a valid pmf.

# %% [markdown]
# For Refund,\
# $p_{X_{R.}|ω_i}('Yes'|'No') = P(R. = 'Yes'|'No') = 4/9$\
# $p_{X_{R.}|ω_i}('No'|'No') = P(R. = 'No'|'No') = 5/9$

# %% [markdown]
# $p_{X_{R.}|ω_i}('Yes'|'Yes') = P(R. = 'Yes'|'Yes') = 1/5$\
# $p_{X_{R.}|ω_i}('No'|'Yes') = P(R. = 'No'|'Yes') = 4/5$

# %% [markdown]
# For all conditional probabilities for Refund is positive, $\sum p_{X_{R.}|ω_i}(x_j|'Yes') = 1$, $\sum p_{X_{R.}|ω_i}(x_j|'No') = 1$. For Refund,hence,it is a valid pmf.

# %% [markdown]
# ##### (e) Estimate the minimum error rate decision rule for classifying tax evasion using Laplace correction.

# %% [markdown]
# The priori probability is ,
# $$P(\omega_i = 'Yes') = 3/10$$
# $$P(\omega_i = 'No') = 7/10$$

# %% [markdown]
# For the minimum error rate decision rule $\omega_1 = 'Yes'$ $\omega_2 = 'No'$ and choosing $\omega_1$,
# $$\Longrightarrow p_{\omega_1|X}(\omega_1|X)\geq p_{\omega_2|X}(\omega_2|X) $$\
# $$\Longrightarrow\frac{p_{X|\omega_1}(X|\omega_1)P(\omega_1)}{P(X)}\geq\frac{p_{X|\omega_2}(X|\omega_2)P(\omega_2)}{p(X)}$$\
# $$\Longrightarrow\frac{p_{X|\omega_1}(X|\omega_1)}{p_{X|\omega_2}(X|\omega_2)} \geq \frac{P(\omega_2)}{p(\omega_1)}$$\
# $$\Longrightarrow\frac{p_{X_{R.}|\omega_1}(x_{R.}|\omega_1)p_{X_{M.S.}|\omega_1}(x_{M.S.}|\omega_1)p_{X_{T.I.}|\omega_1}(x_{T.I.}|\omega_1)}{p_{X_{R.}|\omega_2}(x_{R.}|\omega_2)p_{X_{M.S.}|\omega_2}(x_{M.S.}|\omega_2)p_{X_{T.I.}|\omega_2}(x_{T.I.}|\omega_2)}\geq \frac{P(\omega_2)}{p(\omega_1)}=\frac{7}{3}$$

# %% [markdown]
# So the condition of "Evade" = 'Yes' is when,
# $$\frac{p_{X_{R.}|\omega_1}(x_{R.}|\omega_1)p_{X_{M.S.}|\omega_1}(x_{M.S.}|\omega_1)p_{X_{T.I.}|\omega_1}(x_{T.I.}|\omega_1)}{p_{X_{R.}|\omega_2}(x_{R.}|\omega_2)p_{X_{M.S.}|\omega_2}(x_{M.S.}|\omega_2)p_{X_{T.I.}|\omega_2}(x_{T.I.}|\omega_2)} \geq \frac{7}{3}$$

# %% [markdown]
# ***The conditional probabilities for Marital Status and Refund use the laplace correlation. and the continous predictor use the equation**

# %% [markdown]
# $$P_{X_{T.I.}|\omega}(x_{T.I.} |\omega_1) =\frac{1}{\sqrt{2\pi\times(6.33) }}e^{\frac{(x_{T.I.} - 87.67)^2}{2\times(6.33)}} $$

# %% [markdown]
# $$P_{X_{T.I.}|\omega}(x_{T.I.} |\omega_2) = \frac{1}{\sqrt{2\pi\times(2539.5) }}e^{\frac{(x_{T.I.} - 109.14)^2}{2\times(2539.5)}} $$
